# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier

# %%
train_df = pd.read_csv(Path('Resources/Generator/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/Generator/2020Q1loans.csv'))

# %%
train_df
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1        40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2        11000.0    0.2055       294.81           RENT     45000.0
# 3         4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4        14000.0    0.1797       505.93       MORTGAGE     43000.0
# ...          ...       ...          ...            ...         ...
# 12175    19975.0    0.2565       801.09           RENT     28000.0
# 12176    15000.0    0.1774       540.34           RENT     50000.0
# 12177     3600.0    0.1862       131.28           RENT     60000.0
# 12178    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179    15000.0    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  28.62          0.0             2.0  ...
# 1         Source Verified          n  11.72          2.0             0.0  ...
# 2                Verified          n  37.25          1.0             3.0  ...
# 3            Not Verified          n  42.89          1.0             0.0  ...
# 4         Source Verified          n  22.16          1.0             0.0  ...
# ...                   ...        ...    ...          ...             ...  ...
# 12175        Not Verified          n  28.42          0.0             0.0  ...
# 12176            Verified          n  23.43          4.0             0.0  ...
# 12177        Not Verified          n  28.80          0.0             1.0  ...
# 12178     Source Verified          n  11.44          0.0             0.0  ...
# 12179        Not Verified          n  21.66          1.0             1.0  ...
#
#        percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                  87.5                   0.0        0.0         352260.0
# 1                   0.0                   0.0        0.0         294664.0
# 2                   7.7                   0.0        0.0          92228.0
# 3                 100.0                   0.0        0.0         284273.0
# 4                  25.0                   0.0        0.0         120280.0
# ...                 ...                   ...        ...              ...
# 12175              16.7                   0.0        0.0          50055.0
# 12176              11.1                   0.0        0.0          70324.0
# 12177               0.0                   0.0        0.0          83765.0
# 12178               0.0                   0.0        0.0         189930.0
# 12179             100.0                   0.0        0.0          48968.0
#
#       total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0               62666.0         35000.0                     10000.0
# 1              109911.0          9000.0                     71044.0
# 2               36007.0         33000.0                     46328.0
# 3               52236.0         13500.0                     52017.0
# 4               88147.0         33300.0                     78680.0
# ...                 ...             ...                         ...
# 12175           28192.0         18700.0                     19055.0
# 12176           57025.0         13300.0                     54824.0
# 12177           55156.0         14800.0                     53065.0
# 12178           23748.0          7000.0                     32930.0
# 12179           29786.0          2900.0                     33968.0
#
#        hardship_flag  debt_settlement_flag     target
# 0                  N                     N   low_risk
# 1                  N                     N   low_risk
# 2                  N                     N   low_risk
# 3                  N                     N   low_risk
# 4                  N                     N   low_risk
# ...              ...                   ...        ...
# 12175              N                     N  high_risk
# 12176              N                     N  high_risk
# 12177              N                     N  high_risk
# 12178              N                     N  high_risk
# 12179              N                     N  high_risk
#
# [12180 rows x 84 columns]

# %%
test_df
# Out:
#       loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0       40000.0    0.1033       856.40           RENT    128700.0
# 1       24450.0    0.1430       572.72       MORTGAGE     44574.0
# 2       13500.0    0.1430       316.23            OWN     60000.0
# 3       10625.0    0.1774       268.31           RENT     60000.0
# 4        6375.0    0.1862       232.46           RENT     60000.0
# ...         ...       ...          ...            ...         ...
# 4697    30000.0    0.1240       673.42           RENT    140480.0
# 4698    24000.0    0.0756       747.22           RENT     50000.0
# 4699    10000.0    0.2305       387.36           RENT     33000.0
# 4700     8000.0    0.1862       205.86           RENT     38000.0
# 4701    30000.0    0.2055      1123.34           RENT    180000.0
#
#      verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Source Verified          n  12.47          0.0             1.0  ...
# 1           Not Verified          n  15.05          0.0             1.0  ...
# 2           Not Verified          n  28.72          0.0             0.0  ...
# 3               Verified          n  15.70          0.0             4.0  ...
# 4        Source Verified          n  35.50          0.0             0.0  ...
# ...                  ...        ...    ...          ...             ...  ...
# 4697     Source Verified          n  15.74          0.0             0.0  ...
# 4698        Not Verified          n  26.81          0.0             0.0  ...
# 4699            Verified          n  38.51          0.0             2.0  ...
# 4700     Source Verified          n  16.36          0.0             1.0  ...
# 4701     Source Verified          n  12.06          0.0             0.0  ...
#
#       percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                 57.1                   0.0        0.0          63915.0
# 1                  0.0                   0.0        0.0         136425.0
# 2                  0.0                   0.0        0.0          82124.0
# 3                 20.0                   0.0        0.0          54855.0
# 4                 75.0                   0.0        0.0          90445.0
# ...                ...                   ...        ...              ...
# 4697              28.6                   0.0        0.0         159688.0
# 4698               0.0                   0.0        0.0          62375.0
# 4699               0.0                   0.0        0.0          43250.0
# 4700               0.0                   1.0        0.0          31357.0
# 4701              33.3                   0.0        0.0         218686.0
#
#      total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              49510.0         49400.0                     14515.0
# 1              19439.0         15500.0                     18925.0
# 2              65000.0          5400.0                     61724.0
# 3              50335.0         23200.0                     26255.0
# 4              56541.0         15300.0                     72345.0
# ...                ...             ...                         ...
# 4697          110873.0         48400.0                    107388.0
# 4698           18928.0         13300.0                     30775.0
# 4699           33022.0          8500.0                     29550.0
# 4700           19595.0          1500.0                      9657.0
# 4701          209389.0          5600.0                    209986.0
#
#       hardship_flag  debt_settlement_flag     target
# 0                 Y                     N   low_risk
# 1                 N                     N   low_risk
# 2                 Y                     N   low_risk
# 3                 N                     N   low_risk
# 4                 N                     N   low_risk
# ...             ...                   ...        ...
# 4697              N                     N  high_risk
# 4698              N                     N  high_risk
# 4699              N                     N  high_risk
# 4700              N                     N  high_risk
# 4701              N                     N  high_risk
#
# [4702 rows x 84 columns]

# %%
train_df.dtypes
# Out:
# loan_amnt                     float64
# int_rate                      float64
# installment                   float64
# home_ownership                 object
# annual_inc                    float64
#                                ...
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# hardship_flag                  object
# debt_settlement_flag           object
# target                         object
# Length: 84, dtype: object

# %%
train_df.groupby(["target"]).count()
# Out:
#            loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# target
# high_risk       6090      6090         6090            6090        6090
# low_risk        6090      6090         6090            6090        6090
#
#            verification_status  pymnt_plan   dti  delinq_2yrs  inq_last_6mths  \
# target
# high_risk                 6090        6090  6090         6090            6090
# low_risk                  6090        6090  6090         6090            6090
#
#            ...  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# target     ...
# high_risk  ...            6090              6090                  6090
# low_risk   ...            6090              6090                  6090
#
#            tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# target
# high_risk       6090             6090               6090            6090
# low_risk        6090             6090               6090            6090
#
#            total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# target
# high_risk                        6090           6090                  6090
# low_risk                         6090           6090                  6090
#
# [2 rows x 83 columns]

# %%
# Converting output labels to 0 and 1
y_label = LabelEncoder().fit_transform(train_df['target'])
y_label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# Drop the label to create the X data
X = train_df.drop('target', axis=1)
X
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1        40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2        11000.0    0.2055       294.81           RENT     45000.0
# 3         4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4        14000.0    0.1797       505.93       MORTGAGE     43000.0
# ...          ...       ...          ...            ...         ...
# 12175    19975.0    0.2565       801.09           RENT     28000.0
# 12176    15000.0    0.1774       540.34           RENT     50000.0
# 12177     3600.0    0.1862       131.28           RENT     60000.0
# 12178    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179    15000.0    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  28.62          0.0             2.0  ...
# 1         Source Verified          n  11.72          2.0             0.0  ...
# 2                Verified          n  37.25          1.0             3.0  ...
# 3            Not Verified          n  42.89          1.0             0.0  ...
# 4         Source Verified          n  22.16          1.0             0.0  ...
# ...                   ...        ...    ...          ...             ...  ...
# 12175        Not Verified          n  28.42          0.0             0.0  ...
# 12176            Verified          n  23.43          4.0             0.0  ...
# 12177        Not Verified          n  28.80          0.0             1.0  ...
# 12178     Source Verified          n  11.44          0.0             0.0  ...
# 12179        Not Verified          n  21.66          1.0             1.0  ...
#
#        pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0               100.0              87.5                   0.0        0.0
# 1                85.7               0.0                   0.0        0.0
# 2                94.3               7.7                   0.0        0.0
# 3                92.9             100.0                   0.0        0.0
# 4                84.1              25.0                   0.0        0.0
# ...               ...               ...                   ...        ...
# 12175           100.0              16.7                   0.0        0.0
# 12176            90.5              11.1                   0.0        0.0
# 12177           100.0               0.0                   0.0        0.0
# 12178           100.0               0.0                   0.0        0.0
# 12179            90.0             100.0                   0.0        0.0
#
#       tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0            352260.0            62666.0         35000.0
# 1            294664.0           109911.0          9000.0
# 2             92228.0            36007.0         33000.0
# 3            284273.0            52236.0         13500.0
# 4            120280.0            88147.0         33300.0
# ...               ...                ...             ...
# 12175         50055.0            28192.0         18700.0
# 12176         70324.0            57025.0         13300.0
# 12177         83765.0            55156.0         14800.0
# 12178        189930.0            23748.0          7000.0
# 12179         48968.0            29786.0          2900.0
#
#        total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                         10000.0              N                     N
# 1                         71044.0              N                     N
# 2                         46328.0              N                     N
# 3                         52017.0              N                     N
# 4                         78680.0              N                     N
# ...                           ...            ...                   ...
# 12175                     19055.0              N                     N
# 12176                     54824.0              N                     N
# 12177                     53065.0              N                     N
# 12178                     32930.0              N                     N
# 12179                     33968.0              N                     N
#
# [12180 rows x 83 columns]

# %%
pd.get_dummies(X['verification_status'])
# Out:
#        Not Verified  Source Verified  Verified
# 0                 1                0         0
# 1                 0                1         0
# 2                 0                0         1
# 3                 1                0         0
# 4                 0                1         0
# ...             ...              ...       ...
# 12175             1                0         0
# 12176             0                0         1
# 12177             1                0         0
# 12178             0                1         0
# 12179             1                0         0
#
# [12180 rows x 3 columns]

# %%
# One-hot encoding the entire dataframe
X_dummies = pd.get_dummies(X)
print(X_dummies.columns)
X_dummies
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
#        'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',
#        'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pub_rec_bankruptcies',
#        'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit', 'home_ownership_ANY',
#        'home_ownership_MORTGAGE', 'home_ownership_OWN', 'home_ownership_RENT',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified',
#        'pymnt_plan_n', 'initial_list_status_f', 'initial_list_status_w',
#        'application_type_Individual', 'application_type_Joint App',
#        'hardship_flag_N', 'hardship_flag_Y', 'debt_settlement_flag_N',
#        'debt_settlement_flag_Y'],
#       dtype='object')
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0         7000.0    0.1894       256.38     75000.0  28.62          0.0
# 1        40000.0    0.1614       975.71    102000.0  11.72          2.0
# 2        11000.0    0.2055       294.81     45000.0  37.25          1.0
# 3         4000.0    0.1612       140.87     38000.0  42.89          1.0
# 4        14000.0    0.1797       505.93     43000.0  22.16          1.0
# ...          ...       ...          ...         ...    ...          ...
# 12175    19975.0    0.2565       801.09     28000.0  28.42          0.0
# 12176    15000.0    0.1774       540.34     50000.0  23.43          4.0
# 12177     3600.0    0.1862       131.28     60000.0  28.80          0.0
# 12178    15000.0    0.0881       475.68     62000.0  11.44          0.0
# 12179    15000.0    0.1774       540.34     54080.0  21.66          1.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0                 2.0      20.0      0.0    40414.0  ...
# 1                 0.0      10.0      0.0    43531.0  ...
# 2                 3.0      23.0      0.0     8242.0  ...
# 3                 0.0       7.0      0.0    12767.0  ...
# 4                 0.0      22.0      0.0    11182.0  ...
# ...               ...       ...      ...        ...  ...
# 12175             0.0      15.0      0.0     9679.0  ...
# 12176             0.0      16.0      0.0     3193.0  ...
# 12177             1.0      14.0      0.0    11804.0  ...
# 12178             0.0       5.0      0.0      157.0  ...
# 12179             1.0       5.0      0.0     8349.0  ...
#
#        verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                                 0             1                      1
# 1                                 0             1                      0
# 2                                 1             1                      0
# 3                                 0             1                      0
# 4                                 0             1                      0
# ...                             ...           ...                    ...
# 12175                             0             1                      0
# 12176                             1             1                      0
# 12177                             0             1                      0
# 12178                             0             1                      0
# 12179                             0             1                      1
#
#        initial_list_status_w  application_type_Individual  \
# 0                          0                            1
# 1                          1                            1
# 2                          1                            1
# 3                          1                            0
# 4                          1                            1
# ...                      ...                          ...
# 12175                      1                            1
# 12176                      1                            1
# 12177                      1                            1
# 12178                      1                            0
# 12179                      0                            1
#
#        application_type_Joint App  hardship_flag_N  hardship_flag_Y  \
# 0                               0                1                0
# 1                               0                1                0
# 2                               0                1                0
# 3                               1                1                0
# 4                               0                1                0
# ...                           ...              ...              ...
# 12175                           0                1                0
# 12176                           0                1                0
# 12177                           0                1                0
# 12178                           1                1                0
# 12179                           0                1                0
#
#        debt_settlement_flag_N  debt_settlement_flag_Y
# 0                           1                       0
# 1                           1                       0
# 2                           1                       0
# 3                           1                       0
# 4                           1                       0
# ...                       ...                     ...
# 12175                       1                       0
# 12176                       1                       0
# 12177                       1                       0
# 12178                       1                       0
# 12179                       1                       0
#
# [12180 rows x 92 columns]

# %%
# Convert categorical data to numeric and separate target feature for training data
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_label, random_state=1)

# %%
# Convert categorical data to numeric and separate target feature for testing data

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
#classifier

classifier.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6511220580186098
# Testing Data Score: 0.6532019704433497

# %%
# Scale the data
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train a Random Forest Classifier model and print the model score

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.7799671592775042

# %%
# Scale the data
X_dummies
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0         7000.0    0.1894       256.38     75000.0  28.62          0.0
# 1        40000.0    0.1614       975.71    102000.0  11.72          2.0
# 2        11000.0    0.2055       294.81     45000.0  37.25          1.0
# 3         4000.0    0.1612       140.87     38000.0  42.89          1.0
# 4        14000.0    0.1797       505.93     43000.0  22.16          1.0
# ...          ...       ...          ...         ...    ...          ...
# 12175    19975.0    0.2565       801.09     28000.0  28.42          0.0
# 12176    15000.0    0.1774       540.34     50000.0  23.43          4.0
# 12177     3600.0    0.1862       131.28     60000.0  28.80          0.0
# 12178    15000.0    0.0881       475.68     62000.0  11.44          0.0
# 12179    15000.0    0.1774       540.34     54080.0  21.66          1.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0                 2.0      20.0      0.0    40414.0  ...
# 1                 0.0      10.0      0.0    43531.0  ...
# 2                 3.0      23.0      0.0     8242.0  ...
# 3                 0.0       7.0      0.0    12767.0  ...
# 4                 0.0      22.0      0.0    11182.0  ...
# ...               ...       ...      ...        ...  ...
# 12175             0.0      15.0      0.0     9679.0  ...
# 12176             0.0      16.0      0.0     3193.0  ...
# 12177             1.0      14.0      0.0    11804.0  ...
# 12178             0.0       5.0      0.0      157.0  ...
# 12179             1.0       5.0      0.0     8349.0  ...
#
#        verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                                 0             1                      1
# 1                                 0             1                      0
# 2                                 1             1                      0
# 3                                 0             1                      0
# 4                                 0             1                      0
# ...                             ...           ...                    ...
# 12175                             0             1                      0
# 12176                             1             1                      0
# 12177                             0             1                      0
# 12178                             0             1                      0
# 12179                             0             1                      1
#
#        initial_list_status_w  application_type_Individual  \
# 0                          0                            1
# 1                          1                            1
# 2                          1                            1
# 3                          1                            0
# 4                          1                            1
# ...                      ...                          ...
# 12175                      1                            1
# 12176                      1                            1
# 12177                      1                            1
# 12178                      1                            0
# 12179                      0                            1
#
#        application_type_Joint App  hardship_flag_N  hardship_flag_Y  \
# 0                               0                1                0
# 1                               0                1                0
# 2                               0                1                0
# 3                               1                1                0
# 4                               0                1                0
# ...                           ...              ...              ...
# 12175                           0                1                0
# 12176                           0                1                0
# 12177                           0                1                0
# 12178                           1                1                0
# 12179                           0                1                0
#
#        debt_settlement_flag_N  debt_settlement_flag_Y
# 0                           1                       0
# 1                           1                       0
# 2                           1                       0
# 3                           1                       0
# 4                           1                       0
# ...                       ...                     ...
# 12175                       1                       0
# 12176                       1                       0
# 12177                       1                       0
# 12178                       1                       0
# 12179                       1                       0
#
# [12180 rows x 92 columns]

# %%
from sklearn.feature_selection import SelectFromModel
sel = SelectFromModel(clf)
sel.fit(X_train_scaled, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(n_estimators=500,
#                                                  random_state=1))

# %%
X_selected_train, X_selected_test, y_train, y_test = train_test_split(sel.transform(X_dummies), y_label, random_state=1)
scaler = StandardScaler().fit(X_selected_train)
X_selected_train_scaled = scaler.transform(X_selected_train)
X_selected_test_scaled = scaler.transform(X_selected_test)

# %%
pd.DataFrame(X_selected_train_scaled)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.210252  0.427663 -1.125468 -0.385646  0.234235 -0.709942 -0.592563
# 1    -0.223888 -1.355969 -0.145148 -0.204097 -0.220186 -0.232298  0.625992
# 2    -1.210252  0.682468 -1.114040 -0.097455 -0.428748 -0.189160 -1.323696
# 3    -0.914343 -0.595358 -0.833924 -0.239645 -0.412763 -0.656605 -1.079985
# 4     0.395055 -0.203644 -0.071073 -0.168550 -0.573752 -0.306518 -0.511326
# ...        ...       ...       ...       ...       ...       ...       ...
# 9130  1.443066  0.532247  0.979285  0.258021 -0.093070 -0.201391  0.625992
# 9131  0.644112 -1.015596  0.852006 -0.040578  0.408545 -0.743409 -1.404933
# 9132 -0.046343 -1.462455  0.030374 -0.061907  0.018062  0.946756  1.275887
# 9133 -0.223888  0.682468  0.118443 -0.332069  0.075150 -0.095248 -0.592563
# 9134 -0.655422  1.216797 -0.756017 -0.324959  0.283712 -0.354424 -0.673800
#
#             7         8         9   ...        24        25        26  \
# 0    -1.176580 -1.176384 -0.710800  ...  0.087693 -1.200861 -1.258001
# 1    -0.483312 -0.483135  0.128404  ... -0.895826 -1.015586 -0.380103
# 2    -1.114577 -1.114383 -0.846178  ...  1.489208 -1.318763 -1.369000
# 3    -0.634291 -0.634110 -1.238646  ... -1.731817 -1.638784  0.295980
# 4     0.417650  0.417802  0.291205  ... -0.165212  0.533990  0.487705
# ...        ...       ...       ...  ...       ...       ...       ...
# 9130  1.781772  1.781885  0.481978  ... -0.411092  3.313119  2.122412
# 9131 -0.065887 -0.065722  1.477472  ... -1.773968 -1.369293 -0.753462
# 9132  0.297465  0.297620 -1.077515  ... -1.742355  1.713014  0.608794
# 9133 -0.422967 -0.422792  0.361727  ...  0.084181 -1.655628 -0.632372
# 9134 -0.511538 -0.511361 -0.421514  ... -0.253026  0.281342 -1.187365
#
#             27        28        29        30        31        32        33
# 0    -0.170215 -0.092978 -0.377726 -0.837534 -0.527585 -1.006019 -0.476174
# 1    -0.649628 -0.656672  1.813087 -0.716973 -0.768837 -0.018640 -0.805867
# 2    -0.649628 -0.623513 -0.546250 -0.785297 -0.789183 -0.541833 -0.604555
# 3     0.548904  0.006497  2.655707 -0.843559 -0.769930 -0.718853 -0.662991
# 4    -0.469848 -0.557196  2.655707 -0.845835 -0.722319 -0.274336 -0.818469
# ...        ...       ...       ...       ...       ...       ...       ...
# 9130 -0.709554  0.769142 -0.546250  1.406661  1.710363 -0.419886  1.824887
# 9131  2.286774  2.228114  2.655707 -0.706546 -0.379238 -1.065025 -0.060966
# 9132 -0.529774 -0.590355 -0.040678  0.523517  0.670939  0.244923  0.438955
# 9133 -0.349995 -0.490880 -0.883299 -0.765140 -0.614942 -0.278270 -0.765204
# 9134 -0.170215 -0.391404 -0.209202 -0.662755 -0.209174 -0.329409 -0.138814
#
# [9135 rows x 34 columns]

# %%
# Train the Logistic Regression model on the scaled data and print the model score

clf = LogisticRegression()
clf.fit(X_selected_train_scaled, y_train)
print(f'Training Score: {clf.score(X_selected_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_selected_test_scaled, y_test)}')
# Out:
# Training Score: 0.7089217296113848
# Testing Score: 0.7244663382594417
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_selected_train_scaled, y_train)
print(f'Training Score: {clf.score(X_selected_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_selected_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.7967159277504106
